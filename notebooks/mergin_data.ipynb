# %%
import pandas as pd
from pathlib import Path
import os

base_directory = Path(os.getcwd()).parent

weather_file = "data\\weather_data.csv"
weather_path = os.path.join(base_directory, weather_file)

energy_file = "data\\PL_data.csv"
energy_path= os.path.join(base_directory, energy_file)

# %%
weather_df = pd.read_csv(weather_path, delimiter=",", parse_dates=["time"], index_col="time")
weather_df
# Out:
#                      temperature_2m_c  rain_mm  snowfall_cm  \
# time
# 2015-01-03 01:00:00               1.9      0.0          0.0
# 2015-01-03 02:00:00               1.8      0.0          0.0
# 2015-01-03 03:00:00               1.7      0.0          0.0
# 2015-01-03 04:00:00               1.6      0.0          0.0
# 2015-01-03 05:00:00               1.6      0.0          0.0
# ...                               ...      ...          ...
# 2020-09-30 21:00:00              12.9      0.4          0.0
# 2020-09-30 22:00:00              12.5      0.1          0.0
# 2020-09-30 23:00:00              12.4      0.0          0.0
# 2020-10-01 00:00:00              12.3      0.0          0.0
# 2020-10-01 01:00:00              12.3      0.0          0.0
#
#                      apparent_temperature_c  relative_humidity_2m  \
# time
# 2015-01-03 01:00:00                    -4.1                    87
# 2015-01-03 02:00:00                    -4.3                    87
# 2015-01-03 03:00:00                    -4.5                    86
# 2015-01-03 04:00:00                    -4.7                    84
# 2015-01-03 05:00:00                    -4.9                    83
# ...                                     ...                   ...
# 2020-09-30 21:00:00                    11.4                    92
# 2020-09-30 22:00:00                    11.1                    92
# 2020-09-30 23:00:00                    11.1                    92
# 2020-10-01 00:00:00                    11.2                    92
# 2020-10-01 01:00:00                    11.3                    93
#
#                      weather_code_wmo_code  is_day  temperature_1h  \
# time
# 2015-01-03 01:00:00                      2       0             2.2
# 2015-01-03 02:00:00                      2       0             1.9
# 2015-01-03 03:00:00                      2       0             1.8
# 2015-01-03 04:00:00                      2       0             1.7
# 2015-01-03 05:00:00                      2       0             1.6
# ...                                    ...     ...             ...
# 2020-09-30 21:00:00                     51       0            13.1
# 2020-09-30 22:00:00                     51       0            12.9
# 2020-09-30 23:00:00                      3       0            12.5
# 2020-10-01 00:00:00                      3       0            12.4
# 2020-10-01 01:00:00                      3       0            12.3
#
#                      temperature_24h  temperature_rolling_mean_24h  \
# time
# 2015-01-03 01:00:00             -1.0                      2.916667
# 2015-01-03 02:00:00             -0.1                      2.995833
# 2015-01-03 03:00:00              0.0                      3.066667
# 2015-01-03 04:00:00              0.5                      3.112500
# 2015-01-03 05:00:00              1.1                      3.133333
# ...                              ...                           ...
# 2020-09-30 21:00:00             12.8                     12.645833
# 2020-09-30 22:00:00             12.5                     12.645833
# 2020-09-30 23:00:00             12.2                     12.654167
# 2020-10-01 00:00:00             12.1                     12.662500
# 2020-10-01 01:00:00             12.3                     12.662500
#
#                      apparent_temperature_1h  apparent_temperature_24h  \
# time
# 2015-01-03 01:00:00                     -3.7                      -5.5
# 2015-01-03 02:00:00                     -4.1                      -4.4
# 2015-01-03 03:00:00                     -4.3                      -4.2
# 2015-01-03 04:00:00                     -4.5                      -3.7
# 2015-01-03 05:00:00                     -4.7                      -3.1
# ...                                      ...                       ...
# 2020-09-30 21:00:00                     11.2                      11.1
# 2020-09-30 22:00:00                     11.4                      10.7
# 2020-09-30 23:00:00                     11.1                      10.4
# 2020-10-01 00:00:00                     11.1                      10.3
# 2020-10-01 01:00:00                     11.2                      10.9
#
#                      apparent_temperature_rolling_mean_24h  is_cold  is_hot  \
# time
# 2015-01-03 01:00:00                              -2.570833        1       0
# 2015-01-03 02:00:00                              -2.566667        1       0
# 2015-01-03 03:00:00                              -2.579167        1       0
# 2015-01-03 04:00:00                              -2.620833        1       0
# 2015-01-03 05:00:00                              -2.695833        1       0
# ...                                                    ...      ...     ...
# 2020-09-30 21:00:00                              10.700000        0       0
# 2020-09-30 22:00:00                              10.716667        0       0
# 2020-09-30 23:00:00                              10.745833        0       0
# 2020-10-01 00:00:00                              10.783333        0       0
# 2020-10-01 01:00:00                              10.800000        0       0
#
#                      is_comfortable
# time
# 2015-01-03 01:00:00               0
# 2015-01-03 02:00:00               0
# 2015-01-03 03:00:00               0
# 2015-01-03 04:00:00               0
# 2015-01-03 05:00:00               0
# ...                             ...
# 2020-09-30 21:00:00               1
# 2020-09-30 22:00:00               1
# 2020-09-30 23:00:00               1
# 2020-10-01 00:00:00               1
# 2020-10-01 01:00:00               1
#
# [50352 rows x 16 columns]

# %%
energy_df = pd.read_csv(energy_path, parse_dates=["utc_timestamp"], index_col="utc_timestamp")
energy_df.index.name = "time"
energy_df
# Out:
#                      PL_load MW  hour  dayofweek  month  is_weekend  season  \
# time
# 2015-01-02 02:00:00    13010.58     1          4      1           0       1
# 2015-01-02 03:00:00    13006.90     2          4      1           0       1
# 2015-01-02 04:00:00    13241.45     3          4      1           0       1
# 2015-01-02 05:00:00    13985.83     4          4      1           0       1
# 2015-01-02 06:00:00    15719.83     5          4      1           0       1
# ...                         ...   ...        ...    ...         ...     ...
# 2020-09-30 20:00:00    22467.26    18          2      9           0       4
# 2020-09-30 21:00:00    20788.89    19          2      9           0       4
# 2020-09-30 22:00:00    19040.56    20          2      9           0       4
# 2020-09-30 23:00:00    17697.31    21          2      9           0       4
# 2020-10-01 00:00:00    16640.11    22          2      9           0       4
#
#                      is_holiday  day_night  Load_lag_1h  Load_lag_2h  \
# time
# 2015-01-02 02:00:00           0          0     13258.48     13720.80
# 2015-01-02 03:00:00           0          0     13010.58     13258.48
# 2015-01-02 04:00:00           0          0     13006.90     13010.58
# 2015-01-02 05:00:00           0          0     13241.45     13006.90
# 2015-01-02 06:00:00           0          0     13985.83     13241.45
# ...                         ...        ...          ...          ...
# 2020-09-30 20:00:00           0          0     23201.60     22305.06
# 2020-09-30 21:00:00           0          0     22467.26     23201.60
# 2020-09-30 22:00:00           0          0     20788.89     22467.26
# 2020-09-30 23:00:00           0          0     19040.56     20788.89
# 2020-10-01 00:00:00           0          0     17697.31     19040.56
#
#                      Load_lag_6h  Load_lag_24h  Load_rolling_mean_24h
# time
# 2015-01-02 02:00:00     17264.15      13979.46           14920.307083
# 2015-01-02 03:00:00     16559.75      13453.78           14901.687083
# 2015-01-02 04:00:00     15860.24      13306.00           14898.997500
# 2015-01-02 05:00:00     14705.78      13175.58           14932.757917
# 2015-01-02 06:00:00     13720.80      13165.11           15039.204583
# ...                          ...           ...                    ...
# 2020-09-30 20:00:00     21929.09      22738.93           20276.732500
# 2020-09-30 21:00:00     21794.91      21026.58           20266.828750
# 2020-09-30 22:00:00     21653.08      19305.53           20255.788333
# 2020-09-30 23:00:00     21689.28      17940.21           20245.667500
# 2020-10-01 00:00:00     22305.06      16858.75           20236.557500
#
# [50374 rows x 13 columns]

# %%
combined_df = energy_df.join(weather_df, how="inner")
combined_df
# Out:
#                      PL_load MW  hour  dayofweek  month  is_weekend  season  \
# time
# 2015-01-03 01:00:00    14866.75     0          5      1           1       1
# 2015-01-03 02:00:00    14559.70     1          5      1           1       1
# 2015-01-03 03:00:00    14399.30     2          5      1           1       1
# 2015-01-03 04:00:00    14584.08     3          5      1           1       1
# 2015-01-03 05:00:00    14754.50     4          5      1           1       1
# ...                         ...   ...        ...    ...         ...     ...
# 2020-09-30 20:00:00    22467.26    18          2      9           0       4
# 2020-09-30 21:00:00    20788.89    19          2      9           0       4
# 2020-09-30 22:00:00    19040.56    20          2      9           0       4
# 2020-09-30 23:00:00    17697.31    21          2      9           0       4
# 2020-10-01 00:00:00    16640.11    22          2      9           0       4
#
#                      is_holiday  day_night  Load_lag_1h  Load_lag_2h  ...  \
# time                                                                  ...
# 2015-01-03 01:00:00           0          0     15491.38     16641.70  ...
# 2015-01-03 02:00:00           0          0     14866.75     15491.38  ...
# 2015-01-03 03:00:00           0          0     14559.70     14866.75  ...
# 2015-01-03 04:00:00           0          0     14399.30     14559.70  ...
# 2015-01-03 05:00:00           0          0     14584.08     14399.30  ...
# ...                         ...        ...          ...          ...  ...
# 2020-09-30 20:00:00           0          0     23201.60     22305.06  ...
# 2020-09-30 21:00:00           0          0     22467.26     23201.60  ...
# 2020-09-30 22:00:00           0          0     20788.89     22467.26  ...
# 2020-09-30 23:00:00           0          0     19040.56     20788.89  ...
# 2020-10-01 00:00:00           0          0     17697.31     19040.56  ...
#
#                      is_day  temperature_1h  temperature_24h  \
# time
# 2015-01-03 01:00:00       0             2.2             -1.0
# 2015-01-03 02:00:00       0             1.9             -0.1
# 2015-01-03 03:00:00       0             1.8              0.0
# 2015-01-03 04:00:00       0             1.7              0.5
# 2015-01-03 05:00:00       0             1.6              1.1
# ...                     ...             ...              ...
# 2020-09-30 20:00:00       0            13.1             12.9
# 2020-09-30 21:00:00       0            13.1             12.8
# 2020-09-30 22:00:00       0            12.9             12.5
# 2020-09-30 23:00:00       0            12.5             12.2
# 2020-10-01 00:00:00       0            12.4             12.1
#
#                      temperature_rolling_mean_24h  apparent_temperature_1h  \
# time
# 2015-01-03 01:00:00                      2.916667                     -3.7
# 2015-01-03 02:00:00                      2.995833                     -4.1
# 2015-01-03 03:00:00                      3.066667                     -4.3
# 2015-01-03 04:00:00                      3.112500                     -4.5
# 2015-01-03 05:00:00                      3.133333                     -4.7
# ...                                           ...                      ...
# 2020-09-30 20:00:00                     12.641667                     11.5
# 2020-09-30 21:00:00                     12.645833                     11.2
# 2020-09-30 22:00:00                     12.645833                     11.4
# 2020-09-30 23:00:00                     12.654167                     11.1
# 2020-10-01 00:00:00                     12.662500                     11.1
#
#                      apparent_temperature_24h  \
# time
# 2015-01-03 01:00:00                      -5.5
# 2015-01-03 02:00:00                      -4.4
# 2015-01-03 03:00:00                      -4.2
# 2015-01-03 04:00:00                      -3.7
# 2015-01-03 05:00:00                      -3.1
# ...                                       ...
# 2020-09-30 20:00:00                      11.5
# 2020-09-30 21:00:00                      11.1
# 2020-09-30 22:00:00                      10.7
# 2020-09-30 23:00:00                      10.4
# 2020-10-01 00:00:00                      10.3
#
#                      apparent_temperature_rolling_mean_24h  is_cold  is_hot  \
# time
# 2015-01-03 01:00:00                              -2.570833        1       0
# 2015-01-03 02:00:00                              -2.566667        1       0
# 2015-01-03 03:00:00                              -2.579167        1       0
# 2015-01-03 04:00:00                              -2.620833        1       0
# 2015-01-03 05:00:00                              -2.695833        1       0
# ...                                                    ...      ...     ...
# 2020-09-30 20:00:00                              10.687500        0       0
# 2020-09-30 21:00:00                              10.700000        0       0
# 2020-09-30 22:00:00                              10.716667        0       0
# 2020-09-30 23:00:00                              10.745833        0       0
# 2020-10-01 00:00:00                              10.783333        0       0
#
#                      is_comfortable
# time
# 2015-01-03 01:00:00               0
# 2015-01-03 02:00:00               0
# 2015-01-03 03:00:00               0
# 2015-01-03 04:00:00               0
# 2015-01-03 05:00:00               0
# ...                             ...
# 2020-09-30 20:00:00               1
# 2020-09-30 21:00:00               1
# 2020-09-30 22:00:00               1
# 2020-09-30 23:00:00               1
# 2020-10-01 00:00:00               1
#
# [50361 rows x 29 columns]

# %%
combined_df.columns
# Out:
# Index(['PL_load MW', 'hour', 'dayofweek', 'month', 'is_weekend', 'season',
#        'is_holiday', 'day_night', 'Load_lag_1h', 'Load_lag_2h', 'Load_lag_6h',
#        'Load_lag_24h', 'Load_rolling_mean_24h', 'temperature_2m_c', 'rain_mm',
#        'snowfall_cm', 'apparent_temperature_c', 'relative_humidity_2m',
#        'weather_code_wmo_code', 'is_day', 'temperature_1h', 'temperature_24h',
#        'temperature_rolling_mean_24h', 'apparent_temperature_1h',
#        'apparent_temperature_24h', 'apparent_temperature_rolling_mean_24h',
#        'is_cold', 'is_hot', 'is_comfortable'],
#       dtype='object')

# %%
name = "data\\data_for_training.csv"
full = os.path.join(base_directory, name)
combined_df.to_csv(full)

# %%
combined_df["PL_load MW"].plot(figsize=(12, 4), title="Load Over Time")
# Out:
# <Axes: title={'center': 'Load Over Time'}, xlabel='time'>

# %%
combined_df["PL_load MW"].rolling(24).mean().plot(figsize=(12, 4), title="24h Rolling Average Load")
# Out:
# <Axes: title={'center': '24h Rolling Average Load'}, xlabel='time'>

# %%
import seaborn as sns

sns.boxplot(x="hour", y="PL_load MW", data=combined_df)
# Out:
# <Axes: xlabel='hour', ylabel='PL_load MW'>

# %%
sns.boxplot(x="dayofweek", y="PL_load MW", data=combined_df)
# Out:
# <Axes: xlabel='dayofweek', ylabel='PL_load MW'>

# %%
sns.boxplot(x="month", y="PL_load MW", data=combined_df)
# Out:
# <Axes: xlabel='month', ylabel='PL_load MW'>

# %%
combined_df.plot(x="apparent_temperature_c", y="PL_load MW", kind="scatter", alpha=0.3)
# Out:
# c:\Users\vange\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='apparent_temperature_c', ylabel='PL_load MW'>

# %%
sns.lmplot(x="apparent_temperature_c", y="PL_load MW", data=combined_df)

# %%
combined_df.plot(x="temperature_2m_c", y="PL_load MW", kind="scatter", alpha=0.3)
# Out:
# c:\Users\vange\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='temperature_2m_c', ylabel='PL_load MW'>

# %%
combined_df.loc["2016-01":"2016-03"]["PL_load MW"].plot()
# Out:
# <Axes: xlabel='time'>

# %%
combined_df["PL_load MW"].hist(bins=50)
# Out:
# <Axes: >

# %%
correlation_matrix = combined_df.corr()
correlation_matrix
# Out:
#                                        PL_load MW      hour  dayofweek  \
# PL_load MW                               1.000000  0.233789  -0.335691
# hour                                     0.233789  1.000000  -0.000456
# dayofweek                               -0.335691 -0.000456   1.000000
# month                                   -0.047577 -0.000368   0.002254
# is_weekend                              -0.427817 -0.000477   0.791015
# season                                  -0.122085 -0.000483  -0.002080
# is_holiday                              -0.243674  0.000067   0.014189
# day_night                                0.349835 -0.133776  -0.000429
# Load_lag_1h                              0.962945  0.377040  -0.326641
# Load_lag_2h                              0.869941  0.484892  -0.316460
# Load_lag_6h                              0.346516  0.371853  -0.254149
# Load_lag_24h                             0.779183  0.233859   0.146142
# Load_rolling_mean_24h                    0.583206  0.000264  -0.173653
# temperature_2m_c                        -0.109712  0.084064   0.007183
# rain_mm                                 -0.015386  0.000282   0.003145
# snowfall_cm                              0.065320 -0.009115  -0.021362
# apparent_temperature_c                  -0.133456  0.071924   0.011236
# relative_humidity_2m                    -0.196991 -0.158908   0.004525
# weather_code_wmo_code                    0.049634 -0.019638  -0.008062
# is_day                                   0.363541 -0.127833  -0.000290
# temperature_1h                          -0.123960  0.121885   0.006720
# temperature_24h                         -0.107838  0.084045  -0.001601
# temperature_rolling_mean_24h            -0.278186  0.000204   0.003404
# apparent_temperature_1h                 -0.145805  0.102737   0.010838
# apparent_temperature_24h                -0.133421  0.071860   0.001572
# apparent_temperature_rolling_mean_24h   -0.272214  0.000235   0.007355
# is_cold                                  0.187343 -0.043893  -0.004974
# is_hot                                   0.080645  0.049171   0.015867
# is_comfortable                          -0.222287  0.021021  -0.002316
#
#                                           month  is_weekend    season  \
# PL_load MW                            -0.047577   -0.427817 -0.122085
# hour                                  -0.000368   -0.000477 -0.000483
# dayofweek                              0.002254    0.791015 -0.002080
# month                                  1.000000    0.002383  0.606714
# is_weekend                             0.002383    1.000000 -0.003117
# season                                 0.606714   -0.003117  1.000000
# is_holiday                             0.002650    0.021873 -0.053715
# day_night                             -0.021279   -0.000795  0.075511
# Load_lag_1h                           -0.047493   -0.420348 -0.122242
# Load_lag_2h                           -0.047378   -0.411819 -0.122416
# Load_lag_6h                           -0.046198   -0.361766 -0.123018
# Load_lag_24h                          -0.042735   -0.034199 -0.127366
# Load_rolling_mean_24h                 -0.070853   -0.384789 -0.195320
# temperature_2m_c                       0.248450    0.007867  0.505804
# rain_mm                                0.031132    0.010847  0.056526
# snowfall_cm                           -0.050313   -0.014215 -0.088364
# apparent_temperature_c                 0.258516    0.011497  0.517862
# relative_humidity_2m                   0.111323    0.002933 -0.028244
# weather_code_wmo_code                 -0.012202    0.005687 -0.048886
# is_day                                -0.022722   -0.000542  0.072015
# temperature_1h                         0.248777    0.007459  0.506208
# temperature_24h                        0.257999    0.003619  0.516286
# temperature_rolling_mean_24h           0.269908    0.006537  0.545035
# apparent_temperature_1h                0.258857    0.011221  0.518296
# apparent_temperature_24h               0.268403    0.008942  0.528889
# apparent_temperature_rolling_mean_24h  0.275730    0.011133  0.548238
# is_cold                               -0.233419   -0.006055 -0.522035
# is_hot                                 0.064904    0.011392  0.122016
# is_comfortable                         0.201491    0.000797  0.461187
#
#                                        is_holiday  day_night  Load_lag_1h  \
# PL_load MW                              -0.243674   0.349835     0.962945
# hour                                     0.000067  -0.133776     0.377040
# dayofweek                                0.014189  -0.000429    -0.326641
# month                                    0.002650  -0.021279    -0.047493
# is_weekend                               0.021873  -0.000795    -0.420348
# season                                  -0.053715   0.075511    -0.122242
# is_holiday                               1.000000  -0.004735    -0.241928
# day_night                               -0.004735   1.000000     0.255277
# Load_lag_1h                             -0.241928   0.255277     1.000000
# Load_lag_2h                             -0.239793   0.150796     0.962940
# Load_lag_6h                             -0.226018  -0.358954     0.473749
# Load_lag_24h                            -0.113557   0.350058     0.752785
# Load_rolling_mean_24h                   -0.288907  -0.117520     0.596949
# temperature_2m_c                        -0.033245   0.367243    -0.102548
# rain_mm                                 -0.006861   0.038732    -0.015394
# snowfall_cm                             -0.014968  -0.026916     0.063016
# apparent_temperature_c                  -0.036073   0.334526    -0.127442
# relative_humidity_2m                     0.010220  -0.437643    -0.211844
# weather_code_wmo_code                    0.000253   0.036993     0.047025
# is_day                                  -0.004665   0.983945     0.267704
# temperature_1h                          -0.033011   0.320618    -0.109699
# temperature_24h                         -0.028298   0.365661    -0.100692
# temperature_rolling_mean_24h            -0.032943   0.199185    -0.278255
# apparent_temperature_1h                 -0.035829   0.293715    -0.133440
# apparent_temperature_24h                -0.031729   0.332882    -0.127529
# apparent_temperature_rolling_mean_24h   -0.035157   0.197326    -0.272194
# is_cold                                  0.032264  -0.260917     0.183415
# is_hot                                  -0.022057   0.200532     0.085159
# is_comfortable                          -0.021879   0.166826    -0.220458
#
#                                        Load_lag_2h  ...    is_day  \
# PL_load MW                                0.869941  ...  0.363541
# hour                                      0.484892  ... -0.127833
# dayofweek                                -0.316460  ... -0.000290
# month                                    -0.047378  ... -0.022722
# is_weekend                               -0.411819  ... -0.000542
# season                                   -0.122416  ...  0.072015
# is_holiday                               -0.239793  ... -0.004665
# day_night                                 0.150796  ...  0.983945
# Load_lag_1h                               0.962940  ...  0.267704
# Load_lag_2h                               1.000000  ...  0.162948
# Load_lag_6h                               0.609790  ... -0.349829
# Load_lag_24h                              0.674906  ...  0.363793
# Load_rolling_mean_24h                     0.609704  ... -0.109639
# temperature_2m_c                         -0.105352  ...  0.359364
# rain_mm                                  -0.015238  ...  0.037594
# snowfall_cm                               0.060201  ... -0.025360
# apparent_temperature_c                   -0.130011  ...  0.325926
# relative_humidity_2m                     -0.208167  ... -0.440615
# weather_code_wmo_code                     0.043886  ...  0.037245
# is_day                                    0.162948  ...  1.000000
# temperature_1h                           -0.102552  ...  0.312899
# temperature_24h                          -0.103591  ...  0.357817
# temperature_rolling_mean_24h             -0.278337  ...  0.186893
# apparent_temperature_1h                  -0.127444  ...  0.285208
# apparent_temperature_24h                 -0.130280  ...  0.324334
# apparent_temperature_rolling_mean_24h    -0.272185  ...  0.185055
# is_cold                                   0.183609  ... -0.252124
# is_hot                                    0.081931  ...  0.199755
# is_comfortable                           -0.219177  ...  0.158476
#
#                                        temperature_1h  temperature_24h  \
# PL_load MW                                  -0.123960        -0.107838
# hour                                         0.121885         0.084045
# dayofweek                                    0.006720        -0.001601
# month                                        0.248777         0.257999
# is_weekend                                   0.007459         0.003619
# season                                       0.506208         0.516286
# is_holiday                                  -0.033011        -0.028298
# day_night                                    0.320618         0.365661
# Load_lag_1h                                 -0.109699        -0.100692
# Load_lag_2h                                 -0.102552        -0.103591
# Load_lag_6h                                 -0.182564        -0.226567
# Load_lag_24h                                -0.121015        -0.109637
# Load_rolling_mean_24h                       -0.408319        -0.408859
# temperature_2m_c                             0.993368         0.938474
# rain_mm                                      0.074324         0.099867
# snowfall_cm                                 -0.140978        -0.135784
# apparent_temperature_c                       0.985395         0.932953
# relative_humidity_2m                        -0.414530        -0.376936
# weather_code_wmo_code                       -0.063087        -0.038268
# is_day                                       0.312899         0.357817
# temperature_1h                               1.000000         0.936570
# temperature_24h                              0.936570         1.000000
# temperature_rolling_mean_24h                 0.931366         0.926125
# apparent_temperature_1h                      0.991390         0.931782
# apparent_temperature_24h                     0.934761         0.991388
# apparent_temperature_rolling_mean_24h        0.928191         0.920854
# is_cold                                     -0.818276        -0.782962
# is_hot                                       0.442873         0.412605
# is_comfortable                               0.608081         0.586929
#
#                                        temperature_rolling_mean_24h  \
# PL_load MW                                                -0.278186
# hour                                                       0.000204
# dayofweek                                                  0.003404
# month                                                      0.269908
# is_weekend                                                 0.006537
# season                                                     0.545035
# is_holiday                                                -0.032943
# day_night                                                  0.199185
# Load_lag_1h                                               -0.278255
# Load_lag_2h                                               -0.278337
# Load_lag_6h                                               -0.278675
# Load_lag_24h                                              -0.277391
# Load_rolling_mean_24h                                     -0.436199
# temperature_2m_c                                           0.928843
# rain_mm                                                    0.089941
# snowfall_cm                                               -0.146010
# apparent_temperature_c                                     0.940040
# relative_humidity_2m                                      -0.211759
# weather_code_wmo_code                                     -0.064897
# is_day                                                     0.186893
# temperature_1h                                             0.931366
# temperature_24h                                            0.926125
# temperature_rolling_mean_24h                               1.000000
# apparent_temperature_1h                                    0.942457
# apparent_temperature_24h                                   0.940236
# apparent_temperature_rolling_mean_24h                      0.994711
# is_cold                                                   -0.809521
# is_hot                                                     0.360117
# is_comfortable                                             0.637176
#
#                                        apparent_temperature_1h  \
# PL_load MW                                           -0.145805
# hour                                                  0.102737
# dayofweek                                             0.010838
# month                                                 0.258857
# is_weekend                                            0.011221
# season                                                0.518296
# is_holiday                                           -0.035829
# day_night                                             0.293715
# Load_lag_1h                                          -0.133440
# Load_lag_2h                                          -0.127444
# Load_lag_6h                                          -0.194683
# Load_lag_24h                                         -0.141909
# Load_rolling_mean_24h                                -0.404088
# temperature_2m_c                                      0.986177
# rain_mm                                               0.079620
# snowfall_cm                                          -0.146772
# apparent_temperature_c                                0.994554
# relative_humidity_2m                                 -0.341872
# weather_code_wmo_code                                -0.069377
# is_day                                                0.285208
# temperature_1h                                        0.991390
# temperature_24h                                       0.931782
# temperature_rolling_mean_24h                          0.942457
# apparent_temperature_1h                               1.000000
# apparent_temperature_24h                              0.939490
# apparent_temperature_rolling_mean_24h                 0.948539
# is_cold                                              -0.826286
# is_hot                                                0.453307
# is_comfortable                                        0.611251
#
#                                        apparent_temperature_24h  \
# PL_load MW                                            -0.133421
# hour                                                   0.071860
# dayofweek                                              0.001572
# month                                                  0.268403
# is_weekend                                             0.008942
# season                                                 0.528889
# is_holiday                                            -0.031729
# day_night                                              0.332882
# Load_lag_1h                                           -0.127529
# Load_lag_2h                                           -0.130280
# Load_lag_6h                                           -0.233238
# Load_lag_24h                                          -0.133377
# Load_rolling_mean_24h                                 -0.407430
# temperature_2m_c                                       0.935966
# rain_mm                                                0.100476
# snowfall_cm                                           -0.138202
# apparent_temperature_c                                 0.940060
# relative_humidity_2m                                  -0.322924
# weather_code_wmo_code                                 -0.045079
# is_day                                                 0.324334
# temperature_1h                                         0.934761
# temperature_24h                                        0.991388
# temperature_rolling_mean_24h                           0.940236
# apparent_temperature_1h                                0.939490
# apparent_temperature_24h                               1.000000
# apparent_temperature_rolling_mean_24h                  0.943540
# is_cold                                               -0.789754
# is_hot                                                 0.417532
# is_comfortable                                         0.591405
#
#                                        apparent_temperature_rolling_mean_24h  \
# PL_load MW                                                         -0.272214
# hour                                                                0.000235
# dayofweek                                                           0.007355
# month                                                               0.275730
# is_weekend                                                          0.011133
# season                                                              0.548238
# is_holiday                                                         -0.035157
# day_night                                                           0.197326
# Load_lag_1h                                                        -0.272194
# Load_lag_2h                                                        -0.272185
# Load_lag_6h                                                        -0.272148
# Load_lag_24h                                                       -0.269529
# Load_rolling_mean_24h                                              -0.425258
# temperature_2m_c                                                    0.925980
# rain_mm                                                             0.092891
# snowfall_cm                                                        -0.147677
# apparent_temperature_c                                              0.946135
# relative_humidity_2m                                               -0.180776
# weather_code_wmo_code                                              -0.067705
# is_day                                                              0.185055
# temperature_1h                                                      0.928191
# temperature_24h                                                     0.920854
# temperature_rolling_mean_24h                                        0.994711
# apparent_temperature_1h                                             0.948539
# apparent_temperature_24h                                            0.943540
# apparent_temperature_rolling_mean_24h                               1.000000
# is_cold                                                            -0.811177
# is_hot                                                              0.376452
# is_comfortable                                                      0.631362
#
#                                         is_cold    is_hot  is_comfortable
# PL_load MW                             0.187343  0.080645       -0.222287
# hour                                  -0.043893  0.049171        0.021021
# dayofweek                             -0.004974  0.015867       -0.002316
# month                                 -0.233419  0.064904        0.201491
# is_weekend                            -0.006055  0.011392        0.000797
# season                                -0.522035  0.122016        0.461187
# is_holiday                             0.032264 -0.022057       -0.021879
# day_night                             -0.260917  0.200532        0.166826
# Load_lag_1h                            0.183415  0.085159       -0.220458
# Load_lag_2h                            0.183609  0.081931       -0.219177
# Load_lag_6h                            0.236970 -0.021299       -0.224904
# Load_lag_24h                           0.185663  0.072151       -0.216748
# Load_rolling_mean_24h                  0.394246 -0.079396       -0.354113
# temperature_2m_c                      -0.821807  0.448816        0.608866
# rain_mm                               -0.069988 -0.016807        0.076964
# snowfall_cm                            0.140633 -0.029341       -0.125852
# apparent_temperature_c                -0.829609  0.458323        0.612252
# relative_humidity_2m                   0.265951 -0.296159       -0.128175
# weather_code_wmo_code                  0.077539 -0.056197       -0.051127
# is_day                                -0.252124  0.199755        0.158476
# temperature_1h                        -0.818276  0.442873        0.608081
# temperature_24h                       -0.782962  0.412605        0.586929
# temperature_rolling_mean_24h          -0.809521  0.360117        0.637176
# apparent_temperature_1h               -0.826286  0.453307        0.611251
# apparent_temperature_24h              -0.789754  0.417532        0.591405
# apparent_temperature_rolling_mean_24h -0.811177  0.376452        0.631362
# is_cold                                1.000000 -0.208632       -0.894894
# is_hot                                -0.208632  1.000000       -0.249753
# is_comfortable                        -0.894894 -0.249753        1.000000
#
# [29 rows x 29 columns]

# %%
correlation_matrix["PL_load MW"].sort_values(ascending=False)
# Out:
# PL_load MW                               1.000000
# Load_lag_1h                              0.962945
# Load_lag_2h                              0.869941
# Load_lag_24h                             0.779183
# Load_rolling_mean_24h                    0.583206
# is_day                                   0.363541
# day_night                                0.349835
# Load_lag_6h                              0.346516
# hour                                     0.233789
# is_cold                                  0.187343
# is_hot                                   0.080645
# snowfall_cm                              0.065320
# weather_code_wmo_code                    0.049634
# rain_mm                                 -0.015386
# month                                   -0.047577
# temperature_24h                         -0.107838
# temperature_2m_c                        -0.109712
# season                                  -0.122085
# temperature_1h                          -0.123960
# apparent_temperature_24h                -0.133421
# apparent_temperature_c                  -0.133456
# apparent_temperature_1h                 -0.145805
# relative_humidity_2m                    -0.196991
# is_comfortable                          -0.222287
# is_holiday                              -0.243674
# apparent_temperature_rolling_mean_24h   -0.272214
# temperature_rolling_mean_24h            -0.278186
# dayofweek                               -0.335691
# is_weekend                              -0.427817
# Name: PL_load MW, dtype: float64
